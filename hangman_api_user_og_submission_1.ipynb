# %% [markdown]
# # Trexquant Interview Project (The Hangman Game)
#
# * Copyright Trexquant Investment LP. All Rights Reserved.
# * Redistribution of this question without written consent from Trexquant is prohibited

# %% [markdown]
# ## Instruction:
# For this coding test, your mission is to write an algorithm that plays the game of Hangman through our API server.
#
# When a user plays Hangman, the server first selects a secret word at random from a list. The server then returns a row of underscores (space separated)—one for each letter in the secret word—and asks the user to guess a letter. If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# You are required to write a "guess" function that takes current word (with underscores) as input and returns a guess letter. You will use the API codes below to play 1,000 Hangman games. You have the opportunity to practice before you want to start recording your game results.
#
# Your algorithm is permitted to use a training set of approximately 250,000 dictionary words. Your algorithm will be tested on an entirely disjoint set of 250,000 dictionary words. Please note that this means the words that you will ultimately be tested on do NOT appear in the dictionary that you are given. You are not permitted to use any dictionary other than the training dictionary we provided. This requirement will be strictly enforced by code review.
#
# You are provided with a basic, working algorithm. This algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []
        
        full_dictionary_location = "words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)        
        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()
        
        self.current_dictionary = []
        
        self.guessed_letters = []
        self.incorrect_guesses = []
        
        # full_dictionary_location = "dictionaries/words_250000_train.txt"
        # test_dictionary_location = "dictionaries/words_test.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)        
        # self.test_dictionary = self.build_dictionary(test_dictionary_location)
                        
        self.letter_set = sorted(set("".join(self.full_dictionary)))
        
        self.probabilities = [0] * len(self.letter_set)
        
        self.unigram, self.bigram, self.trigram, self.fourgram, self.fivegram = self.build_n_grams(self.full_dictionary)
        
        self.tries_remaining = 6
        
        self.current_dictionary = []
        
        self.wins = []
        self.lose_words = []


    
    @staticmethod
    def determine_hangman_url():
        links = ['https://trexsim.com', 'https://sg.trexsim.com']

        data = {link: 0 for link in links}

        for link in links:

            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += '/trexsim/hangman'
        return link

    def guess(self, word): # word input example: "_ p p _ e "
        '''
        Given a word with either correctly gussed letters or blanks, this function
        returns the best guess for the next letter based on the n-grams
        '''
        
        # keep track of incorrect guesses to update the n-grams
        self.incorrect_guesses = list(set(self.guessed_letters) - set(word))
        
        # only recalibrate if last guess was incorrect and running low on guesses
        if len(self.guessed_letters) > 0 and self.guessed_letters[-1] in self.incorrect_guesses and self.tries_remaining <= 3:
            self.recalibrate_n_grams()
        
        # clear out probabilities from last guess
        self.probabilities = [0] * len(self.letter_set)

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        clean_word = word[::2]
        
        # run through n-gram function
        return self.fivegram_probs(clean_word)

    def build_n_grams(self, dictionary):
        '''
        build nested dictionary containing occurences for n (1-5) sequences of letters
        unigrams and bigrams have an extra level for length of the word
        for unigram, take only unique letters within each word  
        '''
        unigram = collections.defaultdict(lambda: collections.defaultdict(int))
        bi_gram = collections.defaultdict(lambda: collections.defaultdict(lambda: collections.defaultdict(int)))
        tri_gram = collections.defaultdict(lambda: collections.defaultdict(lambda: collections.defaultdict(int)))
        four_gram = collections.defaultdict(lambda:collections.defaultdict(lambda: collections.defaultdict(lambda: collections.defaultdict(int))))
        five_gram = collections.defaultdict(lambda: collections.defaultdict(lambda:collections.defaultdict(lambda: collections.defaultdict(lambda: collections.defaultdict(int)))))
        
        # go through each word in the dictionary
        for word in dictionary:
            # check each letter in the dictionary and update the n-gram
            for i in range(len(word) - 4):
                bi_gram[len(word)][word[i]][word[i+1]] += 1
                tri_gram[word[i]][word[i+1]][word[i+2]] += 1
                four_gram[word[i]][word[i+1]][word[i+2]][word[i+3]] += 1
                five_gram[word[i]][word[i+1]][word[i+2]][word[i+3]][word[i+4]] += 1
            i = len(word) - 4
            
            # fill out the rest of the n-grams for words too short
            if len(word) == 2:
                bi_gram[len(word)][word[0]][word[1]] += 1
            elif len(word) == 3:
                bi_gram[len(word)][word[0]][word[1]] += 1
                bi_gram[len(word)][word[1]][word[2]] += 1
                tri_gram[word[0]][word[1]][word[2]] += 1
                
            # fill out rest of the (1-4)-grams
            elif len(word) >= 4:
                bi_gram[len(word)][word[i]][word[i+1]] += 1
                bi_gram[len(word)][word[i+1]][word[i+2]] += 1
                bi_gram[len(word)][word[i+2]][word[i+3]] += 1
                tri_gram[word[i]][word[i+1]][word[i+2]] += 1
                tri_gram[word[i+1]][word[i+2]][word[i+3]] += 1
                four_gram[word[i]][word[i+1]][word[i+2]][word[i+3]] += 1
            
            # fill out unigrams
            for letter in set(word):
                unigram[len(word)][letter] += 1
                    
        return unigram, bi_gram, tri_gram, four_gram, five_gram
                    
        
    def recalibrate_n_grams(self):
        '''
        re-tabulates the n-grams after eliminating any incorrectly guessed letters
        updates the dictionary to remove words containing incorrectly guessed letters
        '''
        # updates the dictionary to remove words containing incorrectly guessed letters
        new_dict = [word for word in self.full_dictionary if not set(word).intersection(set(self.incorrect_guesses))]
        self.unigram, self.bigram, self.trigram, self.fourgram, self.fivegram = self.build_n_grams(new_dict)

    
    def fivegram_probs(self, word):
        ''' 
        Input: the word in the "clean" format with no spaces and a '_' if letter has not been guessed
        Flow: uses tri-gram to calculate the probability of a certain letter appearing in a five-letter sequence for a word of given length
        Output: probabilities for each letter to be used in next level
        '''
                
        # vector of probabilities for each letter
        probs = [0] * len(self.letter_set)
        
        total_count = 0
        letter_count = [0] * len(self.letter_set)

        # traverse the word and find patterns that have three consecutive letters where one of them is blank
        for i in range(len(word) - 4):
                        
            # case 1: "letter letter letter letter blank"
            if word[i] != '_' and word[i+1] != '_' and word[i+2] != '_' and word[i+3] != '_' and word[i+4] == '_':
                anchor_letter_1 = word[i]
                anchor_letter_2 = word[i+1]
                anchor_letter_3 = word[i+2]
                anchor_letter_4 = word[i+3]
                
                # calculate occurences of "anchor_letter_1 anchor_letter_2 blank" and for each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.fivegram[anchor_letter_1][anchor_letter_2][anchor_letter_3][anchor_letter_4][letter] > 0 and letter not in self.guessed_letters:
                        total_count += self.fivegram[anchor_letter_1][anchor_letter_2][anchor_letter_3][anchor_letter_4][letter]
                        letter_count[j] += self.fivegram[anchor_letter_1][anchor_letter_2][anchor_letter_3][anchor_letter_4][letter]
        
            # case 2: "letter letter letter blank letter"
            elif word[i] != '_' and word[i+1] != '_' and word[i+2] != '_' and word[i+3] == '_' and word[i+4] != '_':
                anchor_letter_1 = word[i]
                anchor_letter_2 = word[i+1]
                anchor_letter_3 = word[i+2]
                anchor_letter_4 = word[i+4]
                
                # calculate occurences of "anchor_letter_1 blank anchor_letter_2" and for each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.fivegram[anchor_letter_1][anchor_letter_2][anchor_letter_3][letter][anchor_letter_4] > 0 and letter not in self.guessed_letters:
                        total_count += self.fivegram[anchor_letter_1][anchor_letter_2][anchor_letter_3][letter][anchor_letter_4]
                        letter_count[j] += self.fivegram[anchor_letter_1][anchor_letter_2][anchor_letter_3][letter][anchor_letter_4]
               
            # case 3: letter letter blank letter letter
            elif word[i] != '_' and word[i+1] != '_' and word[i+2] == '_' and word[i+3] != '_' and word[i+4] != '_':
                anchor_letter_1 = word[i]
                anchor_letter_2 = word[i+1]
                anchor_letter_3 = word[i+3]
                anchor_letter_4 = word[i+4]
                
                # calculate occurences of "blank anchor_letter_1 anchor_letter_2" and for each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.fivegram[anchor_letter_1][anchor_letter_2][letter][anchor_letter_3][anchor_letter_4] > 0 and letter not in self.guessed_letters:
                        total_count += self.fivegram[anchor_letter_1][anchor_letter_2][letter][anchor_letter_3][anchor_letter_4]
                        letter_count[j] += self.fivegram[anchor_letter_1][anchor_letter_2][letter][anchor_letter_3][anchor_letter_4]
               
            # case 4: letter blank letter letter letter
            elif word[i] != '_' and word[i+1] == '_' and word[i+2] != '_' and word[i+3] != '_' and word[i+4] != '_':
                anchor_letter_1 = word[i]
                anchor_letter_2 = word[i+2]
                anchor_letter_3 = word[i+3]
                anchor_letter_4 = word[i+4]
                
                # calculate occurences of "blank anchor_letter_1 anchor_letter_2" and for each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.fivegram[anchor_letter_1][letter][anchor_letter_2][anchor_letter_3][anchor_letter_4] > 0 and letter not in self.guessed_letters:
                        total_count += self.fivegram[anchor_letter_1][letter][anchor_letter_2][anchor_letter_3][anchor_letter_4]
                        letter_count[j] += self.fivegram[anchor_letter_1][letter][anchor_letter_2][anchor_letter_3][anchor_letter_4]
        
            # case 5: blank letter letter letter letter
            elif word[i] == '_' and word[i+1] != '_' and word[i+2] != '_' and word[i+3] != '_' and word[i+4] != '_':
                anchor_letter_1 = word[i+1]
                anchor_letter_2 = word[i+2]
                anchor_letter_3 = word[i+3]
                anchor_letter_4 = word[i+4]
                
                # calculate occurences of "blank anchor_letter_1 anchor_letter_2" and for each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.fivegram[letter][anchor_letter_1][anchor_letter_2][anchor_letter_3][anchor_letter_4] > 0 and letter not in self.guessed_letters:
                        total_count += self.fivegram[letter][anchor_letter_1][anchor_letter_2][anchor_letter_3][anchor_letter_4]
                        letter_count[j] += self.fivegram[letter][anchor_letter_1][anchor_letter_2][anchor_letter_3][anchor_letter_4]
        
        # calculate the probabilities of each letter appearing
        if total_count > 0:
            for i in range(len(self.letter_set)):
                probs[i] = letter_count[i] / total_count
        
        # interpolate probabilities between trigram and bigram
        for i, p in enumerate(self.probabilities):
            self.probabilities[i] = p + probs[i] * (0.40)
        
        # run the next level down
        return self.fourgram_probs(word)
    
    def fourgram_probs(self, word):
        ''' 
        Input: the word in the "clean" format with no spaces and a '_' if letter has not been guessed
        Flow: uses tri-gram to calculate the probability of a certain letter appearing in a four-letter sequence for a word of given length
        Output: probabilities for each letter to be used in next level
        '''
                
        # vector of probabilities for each letter
        probs = [0] * len(self.letter_set)
        
        total_count = 0
        letter_count = [0] * len(self.letter_set)

        # traverse the word and find patterns that have three consecutive letters where one of them is blank
        for i in range(len(word) - 3):
                        
            # case 1: "letter letter letter blank"
            if word[i] != '_' and word[i+1] != '_' and word[i+2] != '_' and word[i+3] == '_':
                anchor_letter_1 = word[i]
                anchor_letter_2 = word[i+1]
                anchor_letter_3 = word[i+2]
                
                # calculate occurences of "anchor_letter_1 anchor_letter_2 blank" and for each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.fourgram[anchor_letter_1][anchor_letter_2][anchor_letter_3][letter] > 0 and letter not in self.guessed_letters:
                        total_count += self.fourgram[anchor_letter_1][anchor_letter_2][anchor_letter_3][letter]
                        letter_count[j] += self.fourgram[anchor_letter_1][anchor_letter_2][anchor_letter_3][letter]
        
            # case 2: "letter letter blank letter"
            elif word[i] != '_' and word[i+1] != '_' and word[i+2] == '_' and word[i+3] != '_':
                anchor_letter_1 = word[i]
                anchor_letter_2 = word[i+1]
                anchor_letter_3 = word[i+3]
                
                # calculate occurences of "anchor_letter_1 blank anchor_letter_2" and for each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.fourgram[anchor_letter_1][anchor_letter_2][letter][anchor_letter_3] > 0 and letter not in self.guessed_letters:
                        total_count += self.fourgram[anchor_letter_1][anchor_letter_2][letter][anchor_letter_3]
                        letter_count[j] += self.fourgram[anchor_letter_1][anchor_letter_2][letter][anchor_letter_3]
               
            # case 3: letter blank letter letter
            elif word[i] != '_' and word[i+1] == '_' and word[i+2] != '_' and word[i+3] != '_':
                anchor_letter_1 = word[i]
                anchor_letter_2 = word[i+2]
                anchor_letter_3 = word[i+3]
                
                # calculate occurences of "blank anchor_letter_1 anchor_letter_2" and for each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.fourgram[anchor_letter_1][letter][anchor_letter_2][anchor_letter_3] > 0 and letter not in self.guessed_letters:
                        total_count += self.fourgram[anchor_letter_1][letter][anchor_letter_2][anchor_letter_3]
                        letter_count[j] += self.fourgram[anchor_letter_1][letter][anchor_letter_2][anchor_letter_3]
               
            # case 4: blank letter letter letter
            elif word[i] == '_' and word[i+1] != '_' and word[i+2] != '_' and word[i+3] != '_':
                anchor_letter_1 = word[i+1]
                anchor_letter_2 = word[i+2]
                anchor_letter_3 = word[i+3]
                
                # calculate occurences of "blank anchor_letter_1 anchor_letter_2" and for each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.fourgram[letter][anchor_letter_1][anchor_letter_2][anchor_letter_3] > 0 and letter not in self.guessed_letters:
                        total_count += self.fourgram[letter][anchor_letter_1][anchor_letter_2][anchor_letter_3]
                        letter_count[j] += self.fourgram[letter][anchor_letter_1][anchor_letter_2][anchor_letter_3]
        
        # calculate the probabilities of each letter appearing
        if total_count > 0:
            for i in range(len(self.letter_set)):
                probs[i] = letter_count[i] / total_count
        
        # interpolate probabilities between trigram and bigram
        for i, p in enumerate(self.probabilities):
            self.probabilities[i] = p + probs[i] * (0.25)
        
        # run the next level down
        return self.trigram_probs(word)

    def trigram_probs(self, word):
        ''' 
        Input: the word in the "clean" format with no spaces and a '_' if letter has not been guessed
        Flow: uses tri-gram to calculate the probability of a certain letter appearing in a three-letter sequence for a word of given length
        Output: probabilities for each letter to be used in next level
        '''
                
        # vector of probabilities for each letter
        probs = [0] * len(self.letter_set)
        
        total_count = 0
        letter_count = [0] * len(self.letter_set)

        # traverse the word and find patterns that have three consecutive letters where one of them is blank
        for i in range(len(word) - 2):
                        
            # case 1: "letter letter blank"
            if word[i] != '_' and word[i+1] != '_' and word[i+2] == '_':
                anchor_letter_1 = word[i]
                anchor_letter_2 = word[i+1]
                
                # calculate occurences of "anchor_letter_1 anchor_letter_2 blank" and for each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.trigram[anchor_letter_1][anchor_letter_2][letter] > 0 and letter not in self.guessed_letters:
                        total_count += self.trigram[anchor_letter_1][anchor_letter_2][letter]
                        letter_count[j] += self.trigram[anchor_letter_1][anchor_letter_2][letter]
        
            # case 2: "letter blank letter"
            elif word[i] != '_' and word[i+1] == '_' and word[i+2] != '_':
                anchor_letter_1 = word[i]
                anchor_letter_2 = word[i+2]
                
                # calculate occurences of "anchor_letter_1 blank anchor_letter_2" and for each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.trigram[anchor_letter_1][letter][anchor_letter_2] > 0 and letter not in self.guessed_letters:
                        total_count += self.trigram[anchor_letter_1][letter][anchor_letter_2]
                        letter_count[j] += self.trigram[anchor_letter_1][letter][anchor_letter_2]
               
            # case 3: blank letter letter
            elif word[i] == '_' and word[i+1] != '_' and word[i+2] != '_':
                anchor_letter_1 = word[i+1]
                anchor_letter_2 = word[i+2]
                
                # calculate occurences of "blank anchor_letter_1 anchor_letter_2" and for each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.trigram[letter][anchor_letter_1][anchor_letter_2] > 0 and letter not in self.guessed_letters:
                        total_count += self.trigram[letter][anchor_letter_1][anchor_letter_2]
                        letter_count[j] += self.trigram[letter][anchor_letter_1][anchor_letter_2]
        
        # calculate the probabilities of each letter appearing
        if total_count > 0:
            for i in range(len(self.letter_set)):
                probs[i] = letter_count[i] / total_count
        
        # interpolate probabilities between trigram and bigram
        for i, p in enumerate(self.probabilities):
            self.probabilities[i] = p + probs[i] * (0.20)
        
        # run the next level down
        return self.bigram_probs(word)
    
    
    def bigram_probs(self, word):
        ''' 
        Input: the word in the "clean" format with no spaces and a '_' if letter has not been guessed
        Flow: uses bi-gram to calculate the probability of a certain letter appearing in a two-letter sequence for a word of given length
              updates the probabilities set in trigram_probs
        Output: probabilities for each letter to be used in next level
        '''
        
        # vector of probabilities for each letter
        probs = [0] * len(self.letter_set)
        
        total_count = 0
        letter_count = [0] * len(self.letter_set)
        
        # traverse the word and find either patterns of "letter blank" or "blank letter"
        for i in range(len(word) - 1):
            # case 1: "letter blank"
            if word[i] != '_' and word[i+1] == '_':
                anchor_letter = word[i]
                
                # calculate occurences of "anchor_letter blank" and each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.bigram[len(word)][anchor_letter][letter] > 0 and letter not in self.guessed_letters:
                        total_count += self.bigram[len(word)][anchor_letter][letter]
                        letter_count[j] += self.bigram[len(word)][anchor_letter][letter]
                            
            # case 2: "blank letter"
            elif word[i] == '_' and word[i+1]!= '_':
                anchor_letter = word[i+1]
                
                # calculate occurences of "blank anchor_letter" and each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.bigram[len(word)][letter][anchor_letter] > 0 and letter not in self.guessed_letters:
                        total_count += self.bigram[len(word)][letter][anchor_letter]
                        letter_count[j] += self.bigram[len(word)][letter][anchor_letter]
                                                                    
        # calculate the probabilities of each letter appearing
        if total_count > 0:
            for i in range(len(self.letter_set)):
                probs[i] = letter_count[i] / total_count

        # interpolate probabilities between trigram and bigram
        for i, p in enumerate(self.probabilities):
            self.probabilities[i] = p + probs[i] * (0.10)
        
        # return letter associated with highest probability
        return self.unigram_probs(word)
    
    
    def unigram_probs(self, word):
        ''' 
        Input: the word in the "clean" format with no spaces and a '_' if letter has not been guessed
        Flow: uses unigram to calculate the probability of a certain letter appearing in a any blank space
              updates the probabilities set in bigram_probs
        Output: letter with the overall highest probability
        '''
                
        # vector of probabilities for each letter
        probs = [0] * len(self.letter_set)
        
        total_count = 0
        letter_count = [0] * len(self.letter_set)
        
        # traverse the word and find blank spaces
        for i in range(len(word)):
            # case 1: "letter blank"
            if word[i] == '_':
                                
                # calculate occurences of pattern and each letter not guessed yet
                for j, letter in enumerate(self.letter_set):
                    if self.unigram[len(word)][letter] > 0 and letter not in self.guessed_letters:
                        total_count += self.unigram[len(word)][letter]
                        letter_count[j] += self.unigram[len(word)][letter]
                       
        # calculate the probabilities of each letter appearing
        if total_count > 0:
            for i in range(len(self.letter_set)):
                probs[i] = letter_count[i] / total_count
                
        # interpolate probabilities
        for i, p in enumerate(self.probabilities):
            self.probabilities[i] = p + probs[i] * (0.05)
        
        # adjust probabilities so they sum to one (not necessary but looks better)
        final_probs = [0] * len(self.letter_set)
        if sum(self.probabilities) > 0:
            for i in range(len(self.probabilities)):
                final_probs[i] = self.probabilities[i] / sum(self.probabilities)
            
        self.probabilities = final_probs
        
        # find letter with largest probability
        max_prob = 0
        guess_letter = ''
        for i, letter in enumerate(self.letter_set):
            if self.probabilities[i] > max_prob:
                max_prob = self.probabilities[i]
                guess_letter = letter
        
        # if no letter chosen from above, pick a random one (extra weight on vowels)
        if guess_letter == '':
            letters = self.letter_set.copy()
            random.shuffle(letters)
            letters_shuffled = ['e','a','i','o','u'] + letters
            for letter in letters_shuffled:
                if letter not in self.guessed_letters:
                    return letter
            
        return guess_letter
        
  
    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
                
    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
         # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.incorrect_guesses = []
        self.probabilities = [0] * len(self.letter_set)
        self.tries_remaining = 6
        self.recalibrate_n_grams()
                        
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.2)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result
    
class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %% [markdown]
# # API Usage Examples

# %% [markdown]
# ## To start a new game:
# 1. Make sure you have implemented your own "guess" method.
# 2. Use the access_token that we sent you to create your HangmanAPI object.
# 3. Start a game by calling "start_game" method.
# 4. If you wish to test your function without being recorded, set "practice" parameter to 1.
# 5. Note: You have a rate limit of 20 new games per minute. DO NOT start more than 20 new games within one minute.

# %%
api = HangmanAPI(access_token="8d066fa9d3c4785c59944618903abd", timeout=2000)

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
api.start_game(practice=1,verbose=True)
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
practice_success_rate = total_practice_successes / total_practice_runs
print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
# Out:
# Successfully start a new game! Game ID: 26512199a16c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e _ r _ '}
# Guessing letter: a
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ e _ r _ '}
# Guessing letter: t
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ e t r _ '}
# Guessing letter: i
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ _ _ i _ e t r _ '}
# Guessing letter: m
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ _ _ i m e t r _ '}
# Guessing letter: o
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ o _ i m e t r _ '}
# Guessing letter: y
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ o _ i m e t r y '}
# Guessing letter: d
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i _ _ o _ i m e t r y '}
# Guessing letter: l
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i _ _ o _ i m e t r y '}
# Guessing letter: s
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i s _ o s i m e t r y '}
# Guessing letter: p
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i s _ o s i m e t r y '}
# Guessing letter: c
# Sever response: {'game_id': '26512199a16c', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i s c o s i m e t r y '}
# Guessing letter: v
# Sever response: {'game_id': '26512199a16c', 'status': 'success', 'tries_remains': 2, 'word': 'v i s c o s i m e t r y '}
# Successfully finished game: 26512199a16c
# run 376 practice games out of an allotted 100,000. practice success rate so far = 0.237

# %% [markdown]
# ## Playing recorded games:
# Please finalize your code prior to running the cell below. Once this code executes once successfully your submission will be finalized. Our system will not allow you to rerun any additional games.
#
# Please note that it is expected that after you successfully run this block of code that subsequent runs will result in the error message "Your account has been deactivated".
#
# Once you've run this section of the code your submission is complete. Please send us your source code via email.

# %%
for i in range(1000):
    print('Playing ', i, ' th game')
    # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    api.start_game(practice=0,verbose=True)
    
    # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)
# Out:
# Playing  0  th game
# Successfully start a new game! Game ID: 0f981fe373e6. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '0f981fe373e6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '0f981fe373e6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '0f981fe373e6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ a _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '0f981fe373e6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a r r a _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '0f981fe373e6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a r r a _ _ _ n '}
# Guessing letter: t
# Sever response: {'game_id': '0f981fe373e6', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a r r a _ _ _ n '}
# Guessing letter: b
# Sever response: {'game_id': '0f981fe373e6', 'status': 'ongoing', 'tries_remains': 3, 'word': 'b a r r a _ _ _ n '}
# Guessing letter: c
# Sever response: {'game_id': '0f981fe373e6', 'status': 'ongoing', 'tries_remains': 3, 'word': 'b a r r a c _ _ n '}
# Guessing letter: k
# Sever response: {'game_id': '0f981fe373e6', 'status': 'ongoing', 'tries_remains': 2, 'word': 'b a r r a c _ _ n '}
# Guessing letter: h
# Sever response: {'game_id': '0f981fe373e6', 'status': 'ongoing', 'tries_remains': 1, 'word': 'b a r r a c _ _ n '}
# Guessing letter: o
# Sever response: {'game_id': '0f981fe373e6', 'status': 'success', 'tries_remains': 1, 'word': 'b a r r a c o o n '}
# Successfully finished game: 0f981fe373e6
# Playing  1  th game
# Successfully start a new game! Game ID: c79a222303d3. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'c79a222303d3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'c79a222303d3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'c79a222303d3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r a _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'c79a222303d3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ r a _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'c79a222303d3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ r a _ _ '}
# Guessing letter: g
# Sever response: {'game_id': 'c79a222303d3', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ r a _ _ '}
# Guessing letter: c
# Sever response: {'game_id': 'c79a222303d3', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ r a _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'c79a222303d3', 'status': 'ongoing', 'tries_remains': 1, 'word': 'l _ r a _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'c79a222303d3', 'status': 'ongoing', 'tries_remains': 1, 'word': 'l o r a _ o '}
# Guessing letter: m
# Sever response: {'game_id': 'c79a222303d3', 'status': 'failed', 'tries_remains': 0, 'word': 'l o r a _ o '}
# Failed game: c79a222303d3. Because of: # of tries exceeded!
# Playing  2  th game
# Successfully start a new game! Game ID: e6c5769857c6. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'e6c5769857c6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'e6c5769857c6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': 'e6c5769857c6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ _ _ e '}
# Guessing letter: n
# Sever response: {'game_id': 'e6c5769857c6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ _ n e '}
# Guessing letter: i
# Sever response: {'game_id': 'e6c5769857c6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ i n e '}
# Guessing letter: l
# Sever response: {'game_id': 'e6c5769857c6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ l l _ _ _ _ _ i n e '}
# Guessing letter: a
# Sever response: {'game_id': 'e6c5769857c6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a l l a _ a _ _ i n e '}
# Guessing letter: c
# Sever response: {'game_id': 'e6c5769857c6', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a l l a _ a _ _ i n e '}
# Guessing letter: b
# Sever response: {'game_id': 'e6c5769857c6', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a l l a _ a _ _ i n e '}
# Guessing letter: m
# Sever response: {'game_id': 'e6c5769857c6', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a l l a _ a m m i n e '}
# Guessing letter: g
# Sever response: {'game_id': 'e6c5769857c6', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a l l a _ a m m i n e '}
# Guessing letter: h
# Sever response: {'game_id': 'e6c5769857c6', 'status': 'failed', 'tries_remains': 0, 'word': '_ a l l a _ a m m i n e '}
# Failed game: e6c5769857c6. Because of: # of tries exceeded!
# Playing  3  th game
# Successfully start a new game! Game ID: bc62703dd96b. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'bc62703dd96b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'bc62703dd96b', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r _ _ _ e _ '}
# Guessing letter: l
# Sever response: {'game_id': 'bc62703dd96b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r _ _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': 'bc62703dd96b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r _ _ _ e s '}
# Guessing letter: n
# Sever response: {'game_id': 'bc62703dd96b', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r _ _ _ e s '}
# Guessing letter: i
# Sever response: {'game_id': 'bc62703dd96b', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r _ _ _ e s '}
# Guessing letter: t
# Sever response: {'game_id': 'bc62703dd96b', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r _ _ _ e s '}
# Guessing letter: d
# Sever response: {'game_id': 'bc62703dd96b', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r _ _ _ e s '}
# Guessing letter: h
# Sever response: {'game_id': 'bc62703dd96b', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r _ _ h e s '}
# Guessing letter: c
# Sever response: {'game_id': 'bc62703dd96b', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r _ c h e s '}
# Guessing letter: a
# Sever response: {'game_id': 'bc62703dd96b', 'status': 'failed', 'tries_remains': 0, 'word': 'r _ c h e s '}
# Failed game: bc62703dd96b. Because of: # of tries exceeded!
# Playing  4  th game
# Successfully start a new game! Game ID: f2f74b5ea322. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'f2f74b5ea322', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': 'f2f74b5ea322', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'f2f74b5ea322', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ t _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': 'f2f74b5ea322', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i t i _ e '}
# Guessing letter: v
# Sever response: {'game_id': 'f2f74b5ea322', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i t i v e '}
# Guessing letter: s
# Sever response: {'game_id': 'f2f74b5ea322', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ i t i v e '}
# Guessing letter: n
# Sever response: {'game_id': 'f2f74b5ea322', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ n i t i v e '}
# Guessing letter: o
# Sever response: {'game_id': 'f2f74b5ea322', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ o n i t i v e '}
# Guessing letter: m
# Sever response: {'game_id': 'f2f74b5ea322', 'status': 'success', 'tries_remains': 4, 'word': 'm o n i t i v e '}
# Successfully finished game: f2f74b5ea322
# Playing  5  th game
# Successfully start a new game! Game ID: b58e544d2314. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'b58e544d2314', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'b58e544d2314', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'b58e544d2314', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ e _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'b58e544d2314', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ n _ _ e _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'b58e544d2314', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ n i _ e _ i _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'b58e544d2314', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ n i _ e _ i _ _ '}
# Guessing letter: z
# Sever response: {'game_id': 'b58e544d2314', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ n i _ e _ i _ _ '}
# Guessing letter: d
# Sever response: {'game_id': 'b58e544d2314', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ n i _ e d i _ _ '}
# Guessing letter: c
# Sever response: {'game_id': 'b58e544d2314', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ n i _ e d i _ _ '}
# Guessing letter: p
# Sever response: {'game_id': 'b58e544d2314', 'status': 'failed', 'tries_remains': 0, 'word': '_ n i _ e d i _ _ '}
# Failed game: b58e544d2314. Because of: # of tries exceeded!
# Playing  6  th game
# Successfully start a new game! Game ID: 014614161634. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '014614161634', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ e _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '014614161634', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ e _ _ _ e r '}
# Guessing letter: t
# Sever response: {'game_id': '014614161634', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ e _ _ t e r '}
# Guessing letter: n
# Sever response: {'game_id': '014614161634', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ e _ _ t e r '}
# Guessing letter: s
# Sever response: {'game_id': '014614161634', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ e _ s t e r '}
# Guessing letter: a
# Sever response: {'game_id': '014614161634', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ e _ s t e r '}
# Guessing letter: i
# Sever response: {'game_id': '014614161634', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ e _ s t e r '}
# Guessing letter: o
# Sever response: {'game_id': '014614161634', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ e _ s t e r '}
# Guessing letter: u
# Sever response: {'game_id': '014614161634', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ e _ s t e r '}
# Guessing letter: y
# Sever response: {'game_id': '014614161634', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ e y s t e r '}
# Guessing letter: k
# Sever response: {'game_id': '014614161634', 'status': 'failed', 'tries_remains': 0, 'word': '_ e _ e y s t e r '}
# Failed game: 014614161634. Because of: # of tries exceeded!
# Playing  7  th game
# Successfully start a new game! Game ID: 33289c4c4be1. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '33289c4c4be1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '33289c4c4be1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e r _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': '33289c4c4be1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e r _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': '33289c4c4be1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e r i _ e '}
# Guessing letter: n
# Sever response: {'game_id': '33289c4c4be1', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e r i _ e '}
# Guessing letter: z
# Sever response: {'game_id': '33289c4c4be1', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e r i _ e '}
# Guessing letter: d
# Sever response: {'game_id': '33289c4c4be1', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e r i _ e '}
# Guessing letter: s
# Sever response: {'game_id': '33289c4c4be1', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e r i _ e '}
# Guessing letter: m
# Sever response: {'game_id': '33289c4c4be1', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e r i m e '}
# Guessing letter: p
# Sever response: {'game_id': '33289c4c4be1', 'status': 'failed', 'tries_remains': 0, 'word': '_ e r i m e '}
# Failed game: 33289c4c4be1. Because of: # of tries exceeded!
# Playing  8  th game
# Successfully start a new game! Game ID: 6524f7ac9219. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '6524f7ac9219', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '6524f7ac9219', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ i _ i _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '6524f7ac9219', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ i _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '6524f7ac9219', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ n _ i _ i n _ '}
# Guessing letter: s
# Sever response: {'game_id': '6524f7ac9219', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ n _ i _ i n _ '}
# Guessing letter: z
# Sever response: {'game_id': '6524f7ac9219', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ n _ i z i n _ '}
# Guessing letter: g
# Sever response: {'game_id': '6524f7ac9219', 'status': 'ongoing', 'tries_remains': 3, 'word': 'g _ _ _ _ n _ i z i n g '}
# Guessing letter: l
# Sever response: {'game_id': '6524f7ac9219', 'status': 'ongoing', 'tries_remains': 2, 'word': 'g _ _ _ _ n _ i z i n g '}
# Guessing letter: r
# Sever response: {'game_id': '6524f7ac9219', 'status': 'ongoing', 'tries_remains': 2, 'word': 'g _ r _ _ n _ i z i n g '}
# Guessing letter: d
# Sever response: {'game_id': '6524f7ac9219', 'status': 'ongoing', 'tries_remains': 2, 'word': 'g _ r _ _ n d i z i n g '}
# Guessing letter: a
# Sever response: {'game_id': '6524f7ac9219', 'status': 'ongoing', 'tries_remains': 2, 'word': 'g _ r _ a n d i z i n g '}
# Guessing letter: m
# Sever response: {'game_id': '6524f7ac9219', 'status': 'ongoing', 'tries_remains': 2, 'word': 'g _ r m a n d i z i n g '}
# Guessing letter: o
# Sever response: {'game_id': '6524f7ac9219', 'status': 'success', 'tries_remains': 2, 'word': 'g o r m a n d i z i n g '}
# Successfully finished game: 6524f7ac9219
# Playing  9  th game
# Successfully start a new game! Game ID: d9b3eb7c13e1. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'd9b3eb7c13e1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'd9b3eb7c13e1', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ a _ a '}
# Guessing letter: r
# Sever response: {'game_id': 'd9b3eb7c13e1', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ a r a '}
# Guessing letter: p
# Sever response: {'game_id': 'd9b3eb7c13e1', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ a r a '}
# Guessing letter: c
# Sever response: {'game_id': 'd9b3eb7c13e1', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ a r a '}
# Guessing letter: h
# Sever response: {'game_id': 'd9b3eb7c13e1', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ h a r a '}
# Guessing letter: t
# Sever response: {'game_id': 'd9b3eb7c13e1', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ h a r a '}
# Guessing letter: s
# Sever response: {'game_id': 'd9b3eb7c13e1', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a _ h a r a '}
# Guessing letter: n
# Sever response: {'game_id': 'd9b3eb7c13e1', 'status': 'failed', 'tries_remains': 0, 'word': 'a _ h a r a '}
# Failed game: d9b3eb7c13e1. Because of: # of tries exceeded!
# Playing  10  th game
# Successfully start a new game! Game ID: b00f4df1376e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'b00f4df1376e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'b00f4df1376e', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r _ _ _ r e _ '}
# Guessing letter: a
# Sever response: {'game_id': 'b00f4df1376e', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r a _ _ r e _ '}
# Guessing letter: n
# Sever response: {'game_id': 'b00f4df1376e', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r a _ _ r e _ '}
# Guessing letter: t
# Sever response: {'game_id': 'b00f4df1376e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r a _ _ r e _ '}
# Guessing letter: s
# Sever response: {'game_id': 'b00f4df1376e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r a s _ r e s '}
# Guessing letter: u
# Sever response: {'game_id': 'b00f4df1376e', 'status': 'success', 'tries_remains': 4, 'word': 'r a s u r e s '}
# Successfully finished game: b00f4df1376e
# Playing  11  th game
# Successfully start a new game! Game ID: 73b469562c66. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '73b469562c66', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e e _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '73b469562c66', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r e e _ _ _ _ e '}
# Guessing letter: p
# Sever response: {'game_id': '73b469562c66', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r e e _ _ _ _ e '}
# Guessing letter: n
# Sever response: {'game_id': '73b469562c66', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r e e n _ _ _ e '}
# Guessing letter: g
# Sever response: {'game_id': '73b469562c66', 'status': 'ongoing', 'tries_remains': 5, 'word': 'g r e e n _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': '73b469562c66', 'status': 'ongoing', 'tries_remains': 4, 'word': 'g r e e n _ _ _ e '}
# Guessing letter: s
# Sever response: {'game_id': '73b469562c66', 'status': 'ongoing', 'tries_remains': 3, 'word': 'g r e e n _ _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': '73b469562c66', 'status': 'ongoing', 'tries_remains': 3, 'word': 'g r e e n _ i _ e '}
# Guessing letter: d
# Sever response: {'game_id': '73b469562c66', 'status': 'ongoing', 'tries_remains': 3, 'word': 'g r e e n _ i d e '}
# Guessing letter: o
# Sever response: {'game_id': '73b469562c66', 'status': 'ongoing', 'tries_remains': 2, 'word': 'g r e e n _ i d e '}
# Guessing letter: c
# Sever response: {'game_id': '73b469562c66', 'status': 'ongoing', 'tries_remains': 1, 'word': 'g r e e n _ i d e '}
# Guessing letter: l
# Sever response: {'game_id': '73b469562c66', 'status': 'failed', 'tries_remains': 0, 'word': 'g r e e n _ i d e '}
# Failed game: 73b469562c66. Because of: # of tries exceeded!
# Playing  12  th game
# Successfully start a new game! Game ID: a0957f150aa1. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'a0957f150aa1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'a0957f150aa1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ r _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'a0957f150aa1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ a r _ a '}
# Guessing letter: i
# Sever response: {'game_id': 'a0957f150aa1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ a r i a '}
# Guessing letter: t
# Sever response: {'game_id': 'a0957f150aa1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ a r i a '}
# Guessing letter: l
# Sever response: {'game_id': 'a0957f150aa1', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ a r i a '}
# Guessing letter: n
# Sever response: {'game_id': 'a0957f150aa1', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e n a r i a '}
# Guessing letter: g
# Sever response: {'game_id': 'a0957f150aa1', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e n a r i a '}
# Guessing letter: c
# Sever response: {'game_id': 'a0957f150aa1', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e n a r i a '}
# Guessing letter: d
# Sever response: {'game_id': 'a0957f150aa1', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e n a r i a '}
# Guessing letter: m
# Sever response: {'game_id': 'a0957f150aa1', 'status': 'failed', 'tries_remains': 0, 'word': '_ e n a r i a '}
# Failed game: a0957f150aa1. Because of: # of tries exceeded!
# Playing  13  th game
# Successfully start a new game! Game ID: 4c38a02ed677. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '4c38a02ed677', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ a _ '}
# Guessing letter: r
# Sever response: {'game_id': '4c38a02ed677', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a _ '}
# Guessing letter: l
# Sever response: {'game_id': '4c38a02ed677', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ a _ '}
# Guessing letter: n
# Sever response: {'game_id': '4c38a02ed677', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ a _ '}
# Guessing letter: s
# Sever response: {'game_id': '4c38a02ed677', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ a _ '}
# Guessing letter: t
# Sever response: {'game_id': '4c38a02ed677', 'status': 'ongoing', 'tries_remains': 2, 'word': 't _ _ a _ '}
# Guessing letter: e
# Sever response: {'game_id': '4c38a02ed677', 'status': 'ongoing', 'tries_remains': 1, 'word': 't _ _ a _ '}
# Guessing letter: i
# Sever response: {'game_id': '4c38a02ed677', 'status': 'failed', 'tries_remains': 0, 'word': 't _ _ a _ '}
# Failed game: 4c38a02ed677. Because of: # of tries exceeded!
# Playing  14  th game
# Successfully start a new game! Game ID: 44d7b27aac61. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '44d7b27aac61', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ e _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '44d7b27aac61', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ e _ _ _ e '}
# Guessing letter: s
# Sever response: {'game_id': '44d7b27aac61', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ e _ _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': '44d7b27aac61', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ e _ _ l e '}
# Guessing letter: b
# Sever response: {'game_id': '44d7b27aac61', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ _ e _ _ l e '}
# Guessing letter: a
# Sever response: {'game_id': '44d7b27aac61', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e _ _ e _ _ l e '}
# Guessing letter: i
# Sever response: {'game_id': '44d7b27aac61', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e _ _ e i _ l e '}
# Guessing letter: g
# Sever response: {'game_id': '44d7b27aac61', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e _ _ e i g l e '}
# Guessing letter: v
# Sever response: {'game_id': '44d7b27aac61', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e _ v e i g l e '}
# Guessing letter: n
# Sever response: {'game_id': '44d7b27aac61', 'status': 'success', 'tries_remains': 2, 'word': 'e n v e i g l e '}
# Successfully finished game: 44d7b27aac61
# Playing  15  th game
# Successfully start a new game! Game ID: 110e28b0cefd. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '110e28b0cefd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '110e28b0cefd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '110e28b0cefd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i n _ _ _ '}
# Guessing letter: g
# Sever response: {'game_id': '110e28b0cefd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i n g _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '110e28b0cefd', 'status': 'ongoing', 'tries_remains': 5, 'word': 'l _ _ _ i n g l _ '}
# Guessing letter: y
# Sever response: {'game_id': '110e28b0cefd', 'status': 'ongoing', 'tries_remains': 5, 'word': 'l _ _ _ i n g l y '}
# Guessing letter: t
# Sever response: {'game_id': '110e28b0cefd', 'status': 'ongoing', 'tries_remains': 4, 'word': 'l _ _ _ i n g l y '}
# Guessing letter: r
# Sever response: {'game_id': '110e28b0cefd', 'status': 'ongoing', 'tries_remains': 4, 'word': 'l _ r _ i n g l y '}
# Guessing letter: s
# Sever response: {'game_id': '110e28b0cefd', 'status': 'ongoing', 'tries_remains': 3, 'word': 'l _ r _ i n g l y '}
# Guessing letter: d
# Sever response: {'game_id': '110e28b0cefd', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l _ r _ i n g l y '}
# Guessing letter: m
# Sever response: {'game_id': '110e28b0cefd', 'status': 'ongoing', 'tries_remains': 1, 'word': 'l _ r _ i n g l y '}
# Guessing letter: k
# Sever response: {'game_id': '110e28b0cefd', 'status': 'ongoing', 'tries_remains': 1, 'word': 'l _ r k i n g l y '}
# Guessing letter: a
# Sever response: {'game_id': '110e28b0cefd', 'status': 'failed', 'tries_remains': 0, 'word': 'l _ r k i n g l y '}
# Failed game: 110e28b0cefd. Because of: # of tries exceeded!
# Playing  16  th game
# Successfully start a new game! Game ID: dc07c08ef75e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'dc07c08ef75e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'dc07c08ef75e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ r _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'dc07c08ef75e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ r _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'dc07c08ef75e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ r _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'dc07c08ef75e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ r _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'dc07c08ef75e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ r i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'dc07c08ef75e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ r i _ n '}
# Guessing letter: o
# Sever response: {'game_id': 'dc07c08ef75e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ r i o n '}
# Guessing letter: u
# Sever response: {'game_id': 'dc07c08ef75e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ u r i o n '}
# Guessing letter: c
# Sever response: {'game_id': 'dc07c08ef75e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e c u r i o n '}
# Guessing letter: d
# Sever response: {'game_id': 'dc07c08ef75e', 'status': 'success', 'tries_remains': 3, 'word': 'd e c u r i o n '}
# Successfully finished game: dc07c08ef75e
# Playing  17  th game
# Successfully start a new game! Game ID: ff5b75441c76. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'ff5b75441c76', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'ff5b75441c76', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'ff5b75441c76', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ _ _ _ _ a _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'ff5b75441c76', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ _ _ _ _ a _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'ff5b75441c76', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a r _ _ _ _ _ a r _ _ '}
# Guessing letter: c
# Sever response: {'game_id': 'ff5b75441c76', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a r c _ _ _ _ a r c _ '}
# Guessing letter: h
# Sever response: {'game_id': 'ff5b75441c76', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a r c h _ _ _ a r c h '}
# Guessing letter: n
# Sever response: {'game_id': 'ff5b75441c76', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a r c h _ _ n a r c h '}
# Guessing letter: o
# Sever response: {'game_id': 'ff5b75441c76', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a r c h _ o n a r c h '}
# Guessing letter: m
# Sever response: {'game_id': 'ff5b75441c76', 'status': 'success', 'tries_remains': 3, 'word': 'a r c h m o n a r c h '}
# Successfully finished game: ff5b75441c76
# Playing  18  th game
# Successfully start a new game! Game ID: 22bdefdf801e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '22bdefdf801e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ e _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '22bdefdf801e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ e _ _ e '}
# Guessing letter: n
# Sever response: {'game_id': '22bdefdf801e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ e n _ e '}
# Guessing letter: t
# Sever response: {'game_id': '22bdefdf801e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ e _ e n _ e '}
# Guessing letter: c
# Sever response: {'game_id': '22bdefdf801e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ c _ _ _ e _ e n c e '}
# Guessing letter: m
# Sever response: {'game_id': '22bdefdf801e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ c _ _ _ e _ e n c e '}
# Guessing letter: l
# Sever response: {'game_id': '22bdefdf801e', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ c _ _ _ e _ e n c e '}
# Guessing letter: d
# Sever response: {'game_id': '22bdefdf801e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ c _ _ _ e _ e n c e '}
# Guessing letter: i
# Sever response: {'game_id': '22bdefdf801e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ c _ _ i e _ e n c e '}
# Guessing letter: s
# Sever response: {'game_id': '22bdefdf801e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ c _ _ i e s e n c e '}
# Guessing letter: g
# Sever response: {'game_id': '22bdefdf801e', 'status': 'failed', 'tries_remains': 0, 'word': '_ c _ _ i e s e n c e '}
# Failed game: 22bdefdf801e. Because of: # of tries exceeded!
# Playing  19  th game
# Successfully start a new game! Game ID: 275b01f1cdcb. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ t _ _ _ _ _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i t _ _ _ _ i _ e '}
# Guessing letter: n
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i t _ n _ _ i _ e '}
# Guessing letter: a
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i t a n _ _ i _ e '}
# Guessing letter: c
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i t a n _ _ i _ e '}
# Guessing letter: l
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'ongoing', 'tries_remains': 5, 'word': 'l i t a n _ _ i _ e '}
# Guessing letter: o
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'ongoing', 'tries_remains': 4, 'word': 'l i t a n _ _ i _ e '}
# Guessing letter: d
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'ongoing', 'tries_remains': 3, 'word': 'l i t a n _ _ i _ e '}
# Guessing letter: g
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l i t a n _ _ i _ e '}
# Guessing letter: s
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l i t a n _ _ i s e '}
# Guessing letter: y
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l i t a n y _ i s e '}
# Guessing letter: w
# Sever response: {'game_id': '275b01f1cdcb', 'status': 'success', 'tries_remains': 2, 'word': 'l i t a n y w i s e '}
# Successfully finished game: 275b01f1cdcb
# Playing  20  th game
# Successfully start a new game! Game ID: faa8f8bac1a6. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'faa8f8bac1a6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e _ e _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'faa8f8bac1a6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ e _ e _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'faa8f8bac1a6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ e n e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'faa8f8bac1a6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ e n e s s '}
# Guessing letter: l
# Sever response: {'game_id': 'faa8f8bac1a6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ e n e s s '}
# Guessing letter: v
# Sever response: {'game_id': 'faa8f8bac1a6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ v e n e s s '}
# Guessing letter: i
# Sever response: {'game_id': 'faa8f8bac1a6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ i _ _ i v e n e s s '}
# Guessing letter: t
# Sever response: {'game_id': 'faa8f8bac1a6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ i _ t i v e n e s s '}
# Guessing letter: a
# Sever response: {'game_id': 'faa8f8bac1a6', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ i _ t i v e n e s s '}
# Guessing letter: c
# Sever response: {'game_id': 'faa8f8bac1a6', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ i c t i v e n e s s '}
# Guessing letter: d
# Sever response: {'game_id': 'faa8f8bac1a6', 'status': 'success', 'tries_remains': 4, 'word': 'a d d i c t i v e n e s s '}
# Successfully finished game: faa8f8bac1a6
# Playing  21  th game
# Successfully start a new game! Game ID: 19e4ebf59ccf. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '19e4ebf59ccf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '19e4ebf59ccf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '19e4ebf59ccf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ _ _ i _ n '}
# Guessing letter: o
# Sever response: {'game_id': '19e4ebf59ccf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ _ _ i o n '}
# Guessing letter: t
# Sever response: {'game_id': '19e4ebf59ccf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ _ t i o n '}
# Guessing letter: a
# Sever response: {'game_id': '19e4ebf59ccf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ a t i o n '}
# Guessing letter: r
# Sever response: {'game_id': '19e4ebf59ccf', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i _ _ a t i o n '}
# Guessing letter: l
# Sever response: {'game_id': '19e4ebf59ccf', 'status': 'ongoing', 'tries_remains': 4, 'word': 'l i _ _ a t i o n '}
# Guessing letter: c
# Sever response: {'game_id': '19e4ebf59ccf', 'status': 'ongoing', 'tries_remains': 3, 'word': 'l i _ _ a t i o n '}
# Guessing letter: z
# Sever response: {'game_id': '19e4ebf59ccf', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l i _ _ a t i o n '}
# Guessing letter: s
# Sever response: {'game_id': '19e4ebf59ccf', 'status': 'ongoing', 'tries_remains': 1, 'word': 'l i _ _ a t i o n '}
# Guessing letter: m
# Sever response: {'game_id': '19e4ebf59ccf', 'status': 'failed', 'tries_remains': 0, 'word': 'l i _ _ a t i o n '}
# Failed game: 19e4ebf59ccf. Because of: # of tries exceeded!
# Playing  22  th game
# Successfully start a new game! Game ID: 17c63a0451ef. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': '17c63a0451ef', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '17c63a0451ef', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ _ _ _ _ _ _ _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '17c63a0451ef', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e r _ _ _ r _ _ _ _ _ _ e _ r _ '}
# Guessing letter: a
# Sever response: {'game_id': '17c63a0451ef', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e r _ _ _ r _ _ _ _ _ _ e _ r _ '}
# Guessing letter: s
# Sever response: {'game_id': '17c63a0451ef', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e r _ _ _ r _ _ _ _ _ _ e _ r _ '}
# Guessing letter: o
# Sever response: {'game_id': '17c63a0451ef', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e r _ _ _ r o _ _ _ o _ e _ r _ '}
# Guessing letter: n
# Sever response: {'game_id': '17c63a0451ef', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e r _ _ _ r o _ _ _ o _ e _ r _ '}
# Guessing letter: t
# Sever response: {'game_id': '17c63a0451ef', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e r _ t _ r o _ _ t o _ e t r _ '}
# Guessing letter: m
# Sever response: {'game_id': '17c63a0451ef', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e r _ t _ r o _ _ t o m e t r _ '}
# Guessing letter: y
# Sever response: {'game_id': '17c63a0451ef', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e r y t _ r o _ y t o m e t r y '}
# Guessing letter: h
# Sever response: {'game_id': '17c63a0451ef', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e r y t h r o _ y t o m e t r y '}
# Guessing letter: p
# Sever response: {'game_id': '17c63a0451ef', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e r y t h r o _ y t o m e t r y '}
# Guessing letter: c
# Sever response: {'game_id': '17c63a0451ef', 'status': 'success', 'tries_remains': 1, 'word': 'e r y t h r o c y t o m e t r y '}
# Successfully finished game: 17c63a0451ef
# Playing  23  th game
# Successfully start a new game! Game ID: 0cc01776fafe. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': '0cc01776fafe', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ i _ _ _ _ i _ _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '0cc01776fafe', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ _ _ _ i _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '0cc01776fafe', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n _ _ _ i _ _ _ _ i _ _ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '0cc01776fafe', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n _ o _ i o _ o _ i _ _ _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '0cc01776fafe', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n _ o _ i o l o _ i _ _ l l _ '}
# Guessing letter: g
# Sever response: {'game_id': '0cc01776fafe', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n _ o _ i o l o g i _ _ l l _ '}
# Guessing letter: c
# Sever response: {'game_id': '0cc01776fafe', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n _ o c i o l o g i c _ l l _ '}
# Guessing letter: a
# Sever response: {'game_id': '0cc01776fafe', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n _ o c i o l o g i c a l l _ '}
# Guessing letter: y
# Sever response: {'game_id': '0cc01776fafe', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n _ o c i o l o g i c a l l y '}
# Guessing letter: s
# Sever response: {'game_id': '0cc01776fafe', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n s o c i o l o g i c a l l y '}
# Guessing letter: u
# Sever response: {'game_id': '0cc01776fafe', 'status': 'success', 'tries_remains': 5, 'word': 'u n s o c i o l o g i c a l l y '}
# Successfully finished game: 0cc01776fafe
# Playing  24  th game
# Successfully start a new game! Game ID: d95998e119a7. # of tries remaining: 6. Word: _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'd95998e119a7', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'd95998e119a7', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': 'd95998e119a7', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': 'd95998e119a7', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ '}
# Guessing letter: p
# Sever response: {'game_id': 'd95998e119a7', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ '}
# Guessing letter: d
# Sever response: {'game_id': 'd95998e119a7', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'd95998e119a7', 'status': 'failed', 'tries_remains': 0, 'word': '_ e _ '}
# Failed game: d95998e119a7. Because of: # of tries exceeded!
# Playing  25  th game
# Successfully start a new game! Game ID: 751ef3afccd5. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': '751ef3afccd5', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ i _ i _ _ _ i _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '751ef3afccd5', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ i _ i _ _ t i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '751ef3afccd5', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ i _ i _ _ t i _ n '}
# Guessing letter: o
# Sever response: {'game_id': '751ef3afccd5', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ i _ i _ _ t i o n '}
# Guessing letter: a
# Sever response: {'game_id': '751ef3afccd5', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ a _ i _ i _ a t i o n '}
# Guessing letter: c
# Sever response: {'game_id': '751ef3afccd5', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ a _ i _ i c a t i o n '}
# Guessing letter: f
# Sever response: {'game_id': '751ef3afccd5', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ a _ i f i c a t i o n '}
# Guessing letter: r
# Sever response: {'game_id': '751ef3afccd5', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r _ _ _ _ _ a _ i f i c a t i o n '}
# Guessing letter: l
# Sever response: {'game_id': '751ef3afccd5', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r _ _ _ l l a _ i f i c a t i o n '}
# Guessing letter: b
# Sever response: {'game_id': '751ef3afccd5', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r _ _ _ l l a b i f i c a t i o n '}
# Guessing letter: e
# Sever response: {'game_id': '751ef3afccd5', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e _ _ l l a b i f i c a t i o n '}
# Guessing letter: y
# Sever response: {'game_id': '751ef3afccd5', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e _ y l l a b i f i c a t i o n '}
# Guessing letter: s
# Sever response: {'game_id': '751ef3afccd5', 'status': 'success', 'tries_remains': 6, 'word': 'r e s y l l a b i f i c a t i o n '}
# Successfully finished game: 751ef3afccd5
# Playing  26  th game
# Successfully start a new game! Game ID: 779c831ef89b. # of tries remaining: 6. Word: _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '779c831ef89b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '779c831ef89b', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '779c831ef89b', 'status': 'ongoing', 'tries_remains': 4, 'word': 'c _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '779c831ef89b', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '779c831ef89b', 'status': 'ongoing', 'tries_remains': 2, 'word': 'c _ _ '}
# Guessing letter: m
# Sever response: {'game_id': '779c831ef89b', 'status': 'ongoing', 'tries_remains': 1, 'word': 'c _ _ '}
# Guessing letter: p
# Sever response: {'game_id': '779c831ef89b', 'status': 'ongoing', 'tries_remains': 1, 'word': 'c _ p '}
# Guessing letter: o
# Sever response: {'game_id': '779c831ef89b', 'status': 'failed', 'tries_remains': 0, 'word': 'c _ p '}
# Failed game: 779c831ef89b. Because of: # of tries exceeded!
# Playing  27  th game
# Successfully start a new game! Game ID: 353e5a7e8e1a. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '353e5a7e8e1a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '353e5a7e8e1a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': '353e5a7e8e1a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: l
# Sever response: {'game_id': '353e5a7e8e1a', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: n
# Sever response: {'game_id': '353e5a7e8e1a', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: t
# Sever response: {'game_id': '353e5a7e8e1a', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': '353e5a7e8e1a', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ _ _ _ e d '}
# Guessing letter: h
# Sever response: {'game_id': '353e5a7e8e1a', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ _ _ _ e d '}
# Failed game: 353e5a7e8e1a. Because of: # of tries exceeded!
# Playing  28  th game
# Successfully start a new game! Game ID: f03f225ebd1e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'f03f225ebd1e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'f03f225ebd1e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ r _ _ e _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'f03f225ebd1e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ r t _ e _ _ _ _ '}
# Guessing letter: h
# Sever response: {'game_id': 'f03f225ebd1e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ r t _ e _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'f03f225ebd1e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ r t _ e _ _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'f03f225ebd1e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ r t l e _ _ l _ '}
# Guessing letter: s
# Sever response: {'game_id': 'f03f225ebd1e', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ _ _ _ r t l e s s l _ '}
# Guessing letter: y
# Sever response: {'game_id': 'f03f225ebd1e', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ _ _ _ r t l e s s l y '}
# Guessing letter: a
# Sever response: {'game_id': 'f03f225ebd1e', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ _ _ _ r t l e s s l y '}
# Guessing letter: o
# Sever response: {'game_id': 'f03f225ebd1e', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ _ _ o r t l e s s l y '}
# Guessing letter: p
# Sever response: {'game_id': 'f03f225ebd1e', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ p p o r t l e s s l y '}
# Guessing letter: u
# Sever response: {'game_id': 'f03f225ebd1e', 'status': 'success', 'tries_remains': 3, 'word': 's u p p o r t l e s s l y '}
# Successfully finished game: f03f225ebd1e
# Playing  29  th game
# Successfully start a new game! Game ID: f7ced53dcd56. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'f7ced53dcd56', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'f7ced53dcd56', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'f7ced53dcd56', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ _ n _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'f7ced53dcd56', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ _ _ n _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'f7ced53dcd56', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ _ _ n _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'f7ced53dcd56', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ _ r n _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'f7ced53dcd56', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ _ _ r n _ _ '}
# Guessing letter: u
# Sever response: {'game_id': 'f7ced53dcd56', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ _ u r n u _ '}
# Guessing letter: b
# Sever response: {'game_id': 'f7ced53dcd56', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ b u r n u _ '}
# Guessing letter: m
# ...
# Playing  990  th game
# Successfully start a new game! Game ID: b6e670a04d1e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i n _ _ _ '}
# Guessing letter: g
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i n g _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i n g l _ '}
# Guessing letter: y
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i n g l y '}
# Guessing letter: t
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ i n g l y '}
# Guessing letter: r
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ i n g l y '}
# Guessing letter: s
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ s s _ _ i n g l y '}
# Guessing letter: d
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ s s _ _ i n g l y '}
# Guessing letter: h
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ s s _ _ i n g l y '}
# Guessing letter: m
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ s s _ m i n g l y '}
# Guessing letter: a
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a s s _ m i n g l y '}
# Guessing letter: o
# Sever response: {'game_id': 'b6e670a04d1e', 'status': 'failed', 'tries_remains': 0, 'word': 'a s s _ m i n g l y '}
# Failed game: b6e670a04d1e. Because of: # of tries exceeded!
# Playing  991  th game
# Successfully start a new game! Game ID: a6e2b56477c2. # of tries remaining: 6. Word: _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'a6e2b56477c2', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': 'a6e2b56477c2', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'a6e2b56477c2', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'a6e2b56477c2', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'a6e2b56477c2', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'a6e2b56477c2', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o _ l '}
# Guessing letter: p
# Sever response: {'game_id': 'a6e2b56477c2', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o _ l '}
# Guessing letter: i
# Sever response: {'game_id': 'a6e2b56477c2', 'status': 'failed', 'tries_remains': 0, 'word': '_ o _ l '}
# Failed game: a6e2b56477c2. Because of: # of tries exceeded!
# Playing  992  th game
# Successfully start a new game! Game ID: 7038bac0c6a1. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '7038bac0c6a1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '7038bac0c6a1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ a _ a '}
# Guessing letter: r
# Sever response: {'game_id': '7038bac0c6a1', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ a _ a '}
# Guessing letter: n
# Sever response: {'game_id': '7038bac0c6a1', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ a _ a '}
# Guessing letter: l
# Sever response: {'game_id': '7038bac0c6a1', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ a l a '}
# Guessing letter: c
# Sever response: {'game_id': '7038bac0c6a1', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ a l a '}
# Guessing letter: h
# Sever response: {'game_id': '7038bac0c6a1', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a _ _ a l a '}
# Guessing letter: p
# Sever response: {'game_id': '7038bac0c6a1', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a _ p a l a '}
# Guessing letter: o
# Sever response: {'game_id': '7038bac0c6a1', 'status': 'failed', 'tries_remains': 0, 'word': '_ a _ p a l a '}
# Failed game: 7038bac0c6a1. Because of: # of tries exceeded!
# Playing  993  th game
# Successfully start a new game! Game ID: 3539138deef2. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '3539138deef2', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '3539138deef2', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '3539138deef2', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '3539138deef2', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ _ n _ '}
# Guessing letter: i
# Sever response: {'game_id': '3539138deef2', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ i n _ '}
# Guessing letter: g
# Sever response: {'game_id': '3539138deef2', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ i n g '}
# Guessing letter: t
# Sever response: {'game_id': '3539138deef2', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ t _ i n g '}
# Guessing letter: l
# Sever response: {'game_id': '3539138deef2', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a l t _ i n g '}
# Guessing letter: h
# Sever response: {'game_id': '3539138deef2', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a l t _ i n g '}
# Guessing letter: w
# Sever response: {'game_id': '3539138deef2', 'status': 'ongoing', 'tries_remains': 3, 'word': 'w a l t _ i n g '}
# Guessing letter: y
# Sever response: {'game_id': '3539138deef2', 'status': 'ongoing', 'tries_remains': 2, 'word': 'w a l t _ i n g '}
# Guessing letter: z
# Sever response: {'game_id': '3539138deef2', 'status': 'success', 'tries_remains': 2, 'word': 'w a l t z i n g '}
# Successfully finished game: 3539138deef2
# Playing  994  th game
# Successfully start a new game! Game ID: 1cf40a4507eb. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1cf40a4507eb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '1cf40a4507eb', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': '1cf40a4507eb', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ e _ _ e _ '}
# Guessing letter: n
# Sever response: {'game_id': '1cf40a4507eb', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ e _ _ e _ '}
# Guessing letter: t
# Sever response: {'game_id': '1cf40a4507eb', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ e _ _ e _ '}
# Guessing letter: l
# Sever response: {'game_id': '1cf40a4507eb', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ l e _ _ e _ '}
# Guessing letter: b
# Sever response: {'game_id': '1cf40a4507eb', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ l e _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': '1cf40a4507eb', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ l e _ d e d '}
# Guessing letter: a
# Sever response: {'game_id': '1cf40a4507eb', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ l e a d e d '}
# Guessing letter: p
# Sever response: {'game_id': '1cf40a4507eb', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ p l e a d e d '}
# Guessing letter: m
# Sever response: {'game_id': '1cf40a4507eb', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ m p l e a d e d '}
# Guessing letter: o
# Sever response: {'game_id': '1cf40a4507eb', 'status': 'failed', 'tries_remains': 0, 'word': '_ m p l e a d e d '}
# Failed game: 1cf40a4507eb. Because of: # of tries exceeded!
# Playing  995  th game
# Successfully start a new game! Game ID: 6e6172c0764b. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '6e6172c0764b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': '6e6172c0764b', 'status': 'ongoing', 'tries_remains': 6, 'word': 't _ _ _ _ _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '6e6172c0764b', 'status': 'ongoing', 'tries_remains': 6, 'word': 't _ _ _ r _ _ _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': '6e6172c0764b', 'status': 'ongoing', 'tries_remains': 6, 'word': 't _ _ _ r _ _ i _ e '}
# Guessing letter: n
# Sever response: {'game_id': '6e6172c0764b', 'status': 'ongoing', 'tries_remains': 5, 'word': 't _ _ _ r _ _ i _ e '}
# Guessing letter: v
# Sever response: {'game_id': '6e6172c0764b', 'status': 'ongoing', 'tries_remains': 4, 'word': 't _ _ _ r _ _ i _ e '}
# Guessing letter: s
# Sever response: {'game_id': '6e6172c0764b', 'status': 'ongoing', 'tries_remains': 3, 'word': 't _ _ _ r _ _ i _ e '}
# Guessing letter: d
# Sever response: {'game_id': '6e6172c0764b', 'status': 'ongoing', 'tries_remains': 2, 'word': 't _ _ _ r _ _ i _ e '}
# Guessing letter: z
# Sever response: {'game_id': '6e6172c0764b', 'status': 'ongoing', 'tries_remains': 1, 'word': 't _ _ _ r _ _ i _ e '}
# Guessing letter: l
# Sever response: {'game_id': '6e6172c0764b', 'status': 'failed', 'tries_remains': 0, 'word': 't _ _ _ r _ _ i _ e '}
# Failed game: 6e6172c0764b. Because of: # of tries exceeded!
# Playing  996  th game
# Successfully start a new game! Game ID: 8cf1f9a07586. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '8cf1f9a07586', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '8cf1f9a07586', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r _ _ _ _ e _ r '}
# Guessing letter: a
# Sever response: {'game_id': '8cf1f9a07586', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r a _ _ _ e _ r '}
# Guessing letter: t
# Sever response: {'game_id': '8cf1f9a07586', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r a _ _ _ e _ r '}
# Guessing letter: n
# Sever response: {'game_id': '8cf1f9a07586', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r a _ _ _ e _ r '}
# Guessing letter: l
# Sever response: {'game_id': '8cf1f9a07586', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r a _ l l e _ r '}
# Guessing letter: i
# Sever response: {'game_id': '8cf1f9a07586', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r a i l l e _ r '}
# Guessing letter: d
# Sever response: {'game_id': '8cf1f9a07586', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r a i l l e _ r '}
# Guessing letter: s
# Sever response: {'game_id': '8cf1f9a07586', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r a i l l e _ r '}
# Guessing letter: g
# Sever response: {'game_id': '8cf1f9a07586', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r a i l l e _ r '}
# Guessing letter: c
# Sever response: {'game_id': '8cf1f9a07586', 'status': 'failed', 'tries_remains': 0, 'word': 'r a i l l e _ r '}
# Failed game: 8cf1f9a07586. Because of: # of tries exceeded!
# Playing  997  th game
# Successfully start a new game! Game ID: 883efea9553f. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '883efea9553f', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '883efea9553f', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ r _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '883efea9553f', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ t _ _ _ _ r _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '883efea9553f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ t _ _ _ _ r _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '883efea9553f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e s t _ s _ _ r _ s '}
# Guessing letter: i
# Sever response: {'game_id': '883efea9553f', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e s t _ s _ _ r _ s '}
# Guessing letter: o
# Sever response: {'game_id': '883efea9553f', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e s t o s _ _ r _ s '}
# Guessing letter: l
# Sever response: {'game_id': '883efea9553f', 'status': 'ongoing', 'tries_remains': 4, 'word': 'l e s t o s _ _ r _ s '}
# Guessing letter: c
# Sever response: {'game_id': '883efea9553f', 'status': 'ongoing', 'tries_remains': 3, 'word': 'l e s t o s _ _ r _ s '}
# Guessing letter: p
# Sever response: {'game_id': '883efea9553f', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l e s t o s _ _ r _ s '}
# Guessing letter: a
# Sever response: {'game_id': '883efea9553f', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l e s t o s a _ r _ s '}
# Guessing letter: u
# Sever response: {'game_id': '883efea9553f', 'status': 'success', 'tries_remains': 2, 'word': 'l e s t o s a u r u s '}
# Successfully finished game: 883efea9553f
# Playing  998  th game
# Successfully start a new game! Game ID: 3cd02613169e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '3cd02613169e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '3cd02613169e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ a _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '3cd02613169e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ a _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '3cd02613169e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a n _ a _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '3cd02613169e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a n t a _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '3cd02613169e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a n t a l _ '}
# Guessing letter: i
# Sever response: {'game_id': '3cd02613169e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a n t a l i '}
# Guessing letter: c
# Sever response: {'game_id': '3cd02613169e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a n t a l i '}
# Guessing letter: h
# Sever response: {'game_id': '3cd02613169e', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a n t a l i '}
# Guessing letter: p
# Sever response: {'game_id': '3cd02613169e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a n t a l i '}
# Guessing letter: m
# Sever response: {'game_id': '3cd02613169e', 'status': 'failed', 'tries_remains': 0, 'word': '_ a n t a l i '}
# Failed game: 3cd02613169e. Because of: # of tries exceeded!
# Playing  999  th game
# ---------------------------------------------------------------------------
# HangmanAPIError                           Traceback (most recent call last)
# Cell In[18], line 4
#       2 print('Playing ', i, ' th game')
#       3 # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
# ----> 4 api.start_game(practice=0,verbose=True)
#       6 # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
#       7 time.sleep(0.5)
#
# Cell In[9], line 498, in HangmanAPI.start_game(self, practice, verbose)
#     495 self.tries_remaining = 6
#     496 self.recalibrate_n_grams()
# --> 498 response = self.request("/new_game", {"practice":practice})
#     499 if response.get('status')=="approved":
#     500     game_id = response.get('game_id')
#
# Cell In[9], line 600, in HangmanAPI.request(self, path, args, post_args, method)
#     597     raise HangmanAPIError('Maintype was not text, or querystring')
#     599 if result and isinstance(result, dict) and result.get("error"):
# --> 600     raise HangmanAPIError(result)
#     601 return result
#
# HangmanAPIError: {'error': 'You have reached 1000 of games', 'status': 'denied'}

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
practice_success_rate = total_practice_successes / total_practice_runs
print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
# Out:
# run 426 practice games out of an allotted 100,000. practice success rate so far = 0.263

# %% [markdown]
# ## To check your game statistics
# 1. Simply use "my_status" method.
# 2. Returns your total number of games, and number of wins.

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
success_rate = total_recorded_successes/total_recorded_runs
print('overall success rate = %.3f' % success_rate)
# Out:
# overall success rate = 0.507
